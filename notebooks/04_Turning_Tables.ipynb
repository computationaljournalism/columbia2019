# %% [markdown]
# <img src=https://i.kinja-img.com/gawker-media/image/upload/s--4GkTfScj--/c_scale,f_auto,fl_progressive,q_80,w_800/f174xi1inclu89xel9ea.jpg width=600>
#
# ## Turning Tables ##
#
# On January 7, Axios published a "scoop" describing the President's daily schedule based on "his private schedule shown to Axios."
#
# >[Scoop: Trump's secret, shrinking schedule](https://www.axios.com/scoop-trumps-secret-shrinking-schedule-1515364904-ab76374a-6252-4570-a804-942b3f851840.html)<br>
# President Trump is starting his official day much later than he did in the early days of his presidency, often around 11am, and holding far fewer meetings, according to copies of his private schedule shown to Axios. This is largely to meet Trump’s demands for more “Executive Time,” which almost always means TV and Twitter time alone in the residence, officials tell us.
#
# Just yesterday, Axios released [the President's complete schedule in PDF format](https://www.documentcloud.org/documents/5720284-Axios-President-Donald-Trump-Private-Schedules.html), prompting a new round of coverage in [The Guardian](https://www.theguardian.com/us-news/2019/feb/03/trump-executive-time-axios), [Vox](https://www.vox.com/policy-and-politics/2019/2/4/18210345/trump-executive-time-axios-private-schedule-leak) and elsewhere.

# %%
# %%HTML
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">A White House aide is weaponizing his schedules, which says a lot about how people in the White House feel about the man they work for <a href="https://t.co/76K7XCzwPD">https://t.co/76K7XCzwPD</a></p>&mdash; Maggie Haberman (@maggieNYT) <a href="https://twitter.com/maggieNYT/status/1092194637958258690?ref_src=twsrc%5Etfw">February 3, 2019</a></blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# Axios published the calendar in PDF. Is that a good or a bad thing?
#
# *PDF (the Portable Document Format)* is really good for representing documents -- creating a standard like this was a huge deal when PDF was introduced. It began as a proprietary format developed by Adobe, but was released as an open standard in 2008. At first, it was a way to format text and images that was independent of the authoring application, the kind of operating system you were using or the hardware you had. In time, the specification included "rich media" like video, and now it even incorporates a seurity model with encryption and digital signatures. But at the end of the day, information that is encoded in a PDF is designed to be read by humans. The fixed format is analogous to having a paper docment.
#
# For whatever reason, it often becomes a vehicle for publishing data -- which isn't such a good thing. We have all seen pages of tables represented as PDF documents, and in such cases you start to see the format's weaknesses. Extracting data from a PDF will depend, first, on the kind of PDF it is. If you can "select" text from the document, you're in luck. There are several tools to help you get reasonably close to the data. If, on the other hand, your pages are essentially images, well, then you have to rely on "optical character recognition" programs that cluster black and white pixels, say, into letters and words and sentences.
#
# In the case of the Axios PDF's, each schedule entry is represented by a few lines of text that we might want to perform analysis on. **Let's start by reading the text and describing what questions you would like to answer about this document (and, in turn, how the President spends his time), and what data we might want to extract from the PDF for each event in his diary.**

# %% [markdown]
# Your answer here

# %% [markdown]
# Axios has made the data available in a CSV (comma-separated values) format, meaning a table or spreadsheet. You can see [the table here](https://docs.google.com/spreadsheets/d/1oITCuVsYdhNXtY7GElLelsrbjRRIPJ1ce-_v-8J1X_A/edit#gid=0). Have a look. Each row represents one of Trump's diary entries and each column represents a certain "measurement" or observation about each event.
#
# Did they reduce each verbal description of the events in the President's schedule into table entries the way you'd hoped? Anything missing?
#
# Download the table as "CSV" and save it in the same folder as your notebook.
#
# **Relation to built-in types**
#
# The table we have downloaded is in a special form. Each row represents a unit of observation (in this case, a diary entry, but last time each row was a tweet contributing to the "learn to code" meme) and each column is a kind of measurement taken on the different object under study. So for the diary entries our "measurements" have to do with start time and end time and duration of meetings, along with location and attendees. Neither dictionaries nor lists completely capture this tabular structure. We have seen attempts at it.
#
# 1. Dictionary of lists. Here's one way to structure the first five rows of the table. Each column is an element of a dictionary, where the `keys` are the column names.

# %%
{
  "week":[1,1,1,1,1],
  "date":["2018-11-07","2018-11-07","2018-11-07","2018-11-07","2018-11-07"],
  "time_start":["08:00","11:00","11:30","12:30","13:30"],
  "time_end":["11:00","11:30","12:30","13:30","17:00"],
  "duration":[3,0.5,1,1,3.5],
  "listed_title":["Executive time","Meeting with the chief of staff","Executive time","Lunch","Executive time"],
  "top_category":["executive_time","meeting","executive_time","lunch","executive_time"],
  "listed_location":["Oval office","Oval office","Oval office","Private dining room","Oval office"],
  "listed_project_officer":[0,0,0,0,0],
  "detail_category":["executive_time","cos_meeting","executive_time","solo_lunch","executive_time"]
}

# Write some code to extract the duration of the third meeting of the day

# %% [markdown]
# 2. Lists of dictionaries. The rows are now organized as dictionaries and each row is an element in a list.

# %%
[
    {"week":1,"date":"2018-11-07","time_start":"08:00","time_end":"11:00","duration":3,"listed_title":"Executive time","top_category":"executive_time","listed_location":"Oval office","listed_project_officer":null,"detail_category":"executive_time"},
    {"week":1,"date":"2018-11-07","time_start":"11:00","time_end":"11:30","duration":0.5,"listed_title":"Meeting with the chief of staff","top_category":"meeting","listed_location":"Oval office","listed_project_officer":null,"detail_category":"cos_meeting"},
    {"week":1,"date":"2018-11-07","time_start":"11:30","time_end":"12:30","duration":1,"listed_title":"Executive time","top_category":"executive_time","listed_location":"Oval office","listed_project_officer":null,"detail_category":"executive_time"},
    {"week":1,"date":"2018-11-07","time_start":"12:30","time_end":"13:30","duration":1,"listed_title":"Lunch","top_category":"lunch","listed_location":"Private dining room","listed_project_officer":null,"detail_category":"solo_lunch"},
    {"week":1,"date":"2018-11-07","time_start":"13:30","time_end":"17:00","duration":3.5,"listed_title":"Executive time","top_category":"executive_time","listed_location":"Oval office","listed_project_officer":null,"detail_category":"executive_time"}
]

# Write code to extract the start and end times of the second event of the day.

# %% [markdown]
# Using Mr. Data Converter, we see that this is yet another way to organize data in a table using the built-in objects. We saw it in our last class.
#
# 3. A list of lists. In Mr. Data Converter this is called JSON - Row Arrays. This one has the slight disadvantge in that the column names are lost.

# %%
[
  [1,"2018-11-07","08:00","11:00",3,"Executive time","executive_time","Oval office",0,"executive_time"],
  [1,"2018-11-07","11:00","11:30",0.5,"Meeting with the chief of staff","meeting","Oval office",0,"cos_meeting"],
  [1,"2018-11-07","11:30","12:30",1,"Executive time","executive_time","Oval office",0,"executive_time"],
  [1,"2018-11-07","12:30","13:30",1,"Lunch","lunch","Private dining room",0,"solo_lunch"],
  [1,"2018-11-07","13:30","17:00",3.5,"Executive time","executive_time","Oval office",0,"executive_time"]
]

# Write some code to extract the 'listed_title' of the second event.

# %% [markdown]
# The tradeoffs between the different formats are dispayed beautifully in Shan Carter's [Mr. Data Converter](https://shancarter.github.io/mr-data-converter/). With this tool, Shan lets you play with different formats. The three above are "JSON - Column Arrays," "JSON - Properties," and "JSON - Row Arrays." Remember, JSON or the JavaScript Object Notation is a format for expressing data that is (essentially) the same as the built-in objects in Python -- numbers, character strings and booleans piled into lists and dictionaries.
#
# So the material we've been learning typically has variants in other languages and data formats.
#
# **Built-in support for CSV's**
#
# Python has some basic built-in support for dealing with CSVs, since it's a common task. You can, for example, read in CSV's row by row (line by line) from a CSV file, much like we did data from Trump's tweets on the first day. Remember that CSV stands for Comma Separated Values. Each line in the file is a row of data -- well, the first represents a "header" of column names. For each subsequent row, the elements corresponding to the different columns are separated by commas. This format is remarkably robust and you will see it often.
#
# One way to work with a CSV file in Python is through a package called `csv`. The main functions you will import are either a CSV `writer` or a CSV `reader`. Let's try the latter on the President's schedule data.

# %%
from csv import reader

# open the file
diary_file = open("Axios _ President Donald Trump Private Schedules, Nov. 7, 2018 to Feb. 2, 2019 - data.csv")

# use the file to create a csv reader called diary_data
diary_data = reader(diary_file)
type(diary_data)

# %% [markdown]
# We read in the file row-by-row by using a global function called `next()`. This is a nice example of languages evolving. It used to be that `next()` was a method of the CSV reader object and so we would call `dairy_data.next()` to walk through the data in the schedule file. But there are enough objects that you "loop" or iterate over, taking one element after the next sequentially, that in moving from Python 2 to Python 3, the `next()` function became a global like `print()` or `help()`. Languages evolve -- there is no sense that one way of doing things is the absolute best (although some approaches do seem like the worst).
#
# So, we grab rows of the CSV file using `next()` and we'll see that each row is a list -- corresponding to the third representation above, the "list of lists." The first list is just the "header" describing what the columns mean.

# %%
next(diary_data)

# %%
next(diary_data)

# %%
next(diary_data)

# %% [markdown]
# So the built-in support for CSV's is minimal. You can walk through a file and pull out one row at a time, each row being a list. The `diary_data` reader object does have one piece of data you can access, one "attribute" -- the line number you're on.
#
# An attribute of an object is information stored with the object that we can again access with "dot" notation. Because we are looking up information and not computing something (like making strings lowercase, say), we don't need parentheses.
#
# So far we have read three lines from our file so we are on line 4 (which means index 3 since we start counting from 0).

# %%
diary_data.line_num

# %% [markdown]
# Now, repopen the file to start from the beginning, create a new `reader` object and print out the duration of Trump's first meeting of November 7.

# %%
from csv import reader

# open the file
diary_file = open("Axios _ President Donald Trump Private Schedules, Nov. 7, 2018 to Feb. 2, 2019 - data.csv")

# use the file to create a csv reader called diary_data
diary_data = reader(diary_file)

# your code here

# %% [markdown]
# **A Pandas DataFrame**
#
# While we can work with CSV's in this way, either via lists of lists, or lists of dictionaries, or dictionaries of lists, or as a CSV `reader`, none of these really captures the kind of functionality we are used to with a spreadsheet program. How would we sort the data according to a single column? How would we take the average duration of Trump's meetings? How would we count up how many entries are marked "Executive Time"? Don't get me wrong, you can do all these things, it's just painful -- having seen the basic data types, it's time to properly jump ahead to the big leagues.
#
# Enter a new object...
#
# In Python, the answer to Excel (or a popular answer) is a so-called Pandas **DataFrame**. Pandas refers to a package contributed by a Python developer who wanted to make working with tabular data easier.
#
# [You can read more about Pandas here](http://pandas.pydata.org/)
#
# [And there are simple tutorials here](http://nbviewer.jupyter.org/github/jvns/pandas-cookbook/blob/v0.1/cookbook/Chapter%201%20-%20Reading%20from%20a%20CSV.ipynb)
#
# <img src=https://covers.oreillystatic.com/images/0636920050896/cat.gif>
#
# Pandas is a **package**. It is written by [Wes McKinney](https://qz.com/1126615/the-story-of-the-most-important-tool-in-data-science/). Remember, packages are the ways in which developers can publish data, functions and a host of new objects for the community to use. Whereas the built-in objects are basic and get us pretty far, often we need something special to make our lives easier. In the case of Pandas, an object of type DataFrame will help us manipulate (compute with, make graphs of, etc) simple tabular data.
#
# We can read a CSV directly into a Data Frame with a function called, well, `read_csv()`. It lives in the `pandas` package and we import it as follows.

# %%
from pandas import read_csv

diary = read_csv("Axios _ President Donald Trump Private Schedules, Nov. 7, 2018 to Feb. 2, 2019 - data.csv")
diary

# %% [markdown]
# We see by scrolling that we list out the first and last 30 rows. If you scroll all the way down to the bottom, you'll see there are 577 rows in total. But you can get at this directly -- a DataFrame object has an attribute that stores its dimensions (number of rows and columns). It's called `shape`.
#
# Again you access attributes with the "dot" notation, and because we are looking up information and not computing something (like making strings lowercase, say), we don't need parentheses.

# %%
diary.shape

# %% [markdown]
# So We have 577 meetings (rows in the table) and 11 variables recorded for each. We can have a look at the "top" and "bottom" of the data set. These are printed with `head()` and `tail()`methods.

# %%
diary.head()

# %%
diary.tail()

# %% [markdown]
# The `head()` and `tail()` methods of a DataFrame gives you five time periods from the start and end of the data (and you can give an argument to see more). It's important to look at the top and bottom of the file to check that everything looks consistent (column entries seem to mean what they should) and see how the data might be organized.
#
# Some of the primary operations we perform on tables are simple ordering of rows and "subsetting" either rows or columns -- identifying data that's worth a second look. Here we use the method `.sort_valeus()` to sort the rows of the data frame according to some variable. Here we take `duration`, from smallest to largest. (How would you sort in descending order of duration? Google!)

# %%
diary.sort_values('duration')

# %% [markdown]
# You can involve more than one column in the sort. Just include their names in a list. The method `.sort_values()` takes either a column name (string) or a list of names (list of strings). If it's a list it orders the rows by the first column name first, then by the values under the second, third and so on column names in the list.

# %%
diary.sort_values(['time_start','duration'])

# %% [markdown]
# In addition to sorting, we might want to focus our attention only on certain columns. We can select columns from a DataFrame using the same convention as with sorting. We provide either a single column name or a list of column names that we'd like to pull out from the data frame.
#
# The syntax is meant to look like that of a dictionary -- You give names, contained in square braces. So here we are keeping the `listed_title` and then the `listed_title` along with the duration.

# %%
diary["listed_title"].head()

# %%
diary[ ["listed_title","duration"] ].head()

# %% [markdown]
# I added an extra space to separate the square braces in `diary[ ]` from the square braces defining the list of column names we wanted `["listed_title","duration"]`. You don't need the space and you probably won't include it, but for the first time seeing it, it might help.
#
# Now, given the data from a single column, we might want to create a table of values. For example, what is the breakdown of the `listed_title` column? The method `.value_counts()` will take a column and tabulate the number of each unique entry. Here we see `Executive time` has the highest count by a long shot.

# %%
diary['listed_title'].value_counts()

# %%
# Write code to tabulate the number of meetings per day

# %% [markdown]
# Pushing a little farter, we can pull out all the `listed_title` data into a single column using subsetting (with square braces and the column name)...

# %%
diary["listed_title"]

# %% [markdown]
# ... and we can ask if they equal `Executive time` or not. This uses our comparison operator `==` but with a Data Frame, it can run down the whole column at once!

# %%
diary["listed_title"] == "Executive time"

# %% [markdown]
# We can use the `True` and `False` data to subset rows of the table -- here we keep just the rows where the title is "`Executive time`". **Keep in mind that our subsetting expressions now work in two ways.**
#
# Using `diary[ ]`, we can select columns by giving a name or list of names. With the next expression we see that if we provide a column of `True` and `False` values, the subsetting will keep just the portion of the table with `True`, or in this case, where we have `Executive time`.

# %%
diary[ diary["listed_title"] == "Executive time" ]

# %% [markdown]
# And now the simplest thing to do is just sum up the total duration spent in executive time. First, let's sum up the durations for the entire data frame...

# %%
diary["duration"].sum()

# %% [markdown]
# ... and then subset the data frame to just the executive time entries and form a sum.

# %%
exec_diary = diary[ diary["listed_title"] == "Executive time" ]
exec_diary["duration"].sum()

# %% [markdown]
# We could use `sum()` as we did with `followers` in our drill, but the nice thing about the method associated with the data frame column is that it removes the missing values when it forms the sum. That makes life easier. There are a few entries that have missing durations -- listed as NaN.
#
# And the headline for so many stories comes from this computation...

# %%
297/503

# %% [markdown]
# For Wednesday, you are going to work with data from the "learn to code" tweets. They are stored as a CSV and we will read them in and ask you to do some things, let you try out some other things on your own.
#
# **Tweets as Python objects**
#
# A tweet can be stored as a dictionary with keys that describe various facts about the tweet. [Twitter describes the meta-data associated with a Tweet](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/intro-to-tweet-json) and it's not a small object. You have information about the text being tweeted, the time it was tweeted as well as facts about the account posting the tweet. The format has expanded over the years, adding more and more information, until now you get everything from lists of "mentions" and "hashtags" to the address of the biopic for the account tweeting.
#
# We pulled a number of interesting features from each tweet and created a CSV, one row per tweet that dealt with the meme "learn to code". This file is big so you have to download it. I put it up [on Dropbox](https://www.dropbox.com/s/ene3qllvkwzolof/learn_tweets.csv?dl=0) -- download it and put it in the same folder as your notebook. Then you should be able to read it in using the commands below.
#
# (The `set_option` function is giving you access to parameters that control how tables are rendered. Here we change the number of characters per cell to a maximum of 280 for obvious reasons.)

# %%
from pandas import read_csv, set_option

# set the maximum number of characters in any cell
set_option("display.max_colwidth", 280)

tweets = read_csv("learn_tweets.csv")

# %% [markdown]
# And let's have a look...

# %%
tweets.head()
# Out:
#             tweet_time      screen_name  \
# 0  2019-01-30 07:43:04    Jayoh_Essaych
# 1  2019-01-30 07:42:56     GlassSpiider
# 2  2019-01-30 07:42:56  Doc_HervNerbler
# 3  2019-01-30 07:42:44   Alexander_tann
# 4  2019-01-30 07:42:40    blake_laytham
#
#                                                                                                                                      full_text  \
# 0                                                         @TMZ Better #learntocode\nBecause you are bad at journalism: https://t.co/rQ2lTpujqP
# 1                                                                                      @dopegirlfresh surprised she didn't say "learn to code"
# 2                                               RT @JayRFifteen: #LearnToCode @RantsOutloud @Dwarfclone @frank_in_penn https://t.co/d63Ve5YpYX
# 3                                                                                                                  @PrisonPlanet lEaRn tO cODe
# 4  RT @AnthonyAbides: Let's be clear: the media is up in arms over "learn to code" - a phrase they created - one week after they whipped up a…
#
#                 id_str  \
# 0  1090591224808001536
# 1  1090591190141960192
# 2  1090591188640456705
# 3  1090591137696567298
# 4  1090591124488667137
#
#                                                                                  source  \
# 0  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2    <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#    retweet  retweet_count  favorite_count  \
# 0    False              0               0
# 1    False              1               0
# 2     True              1               0
# 3    False              0               0
# 4     True             59               0
#
#                                                                                                                                                          description  \
# 0  Defender of the Enlightenment against Globalism, Intolerance, & Leftists.\n\nSelf-identifies as a Christian-American. Preferred pronouns:  thee, thou, and thine.
# 1                                                                                      list of idiosyncratic interests and quirky personality traits • random animal
# 2                                    Justine is my other half ❤️| Libertarian | Arkansas Razorbacks, Dallas Cowboys, Texas Rangers| Ron Paul and SEC Football = GOAT
# 3                                                                                                                                                                UwU
# 4                                                                                                   @Universityofky and @UK_Patterson Alum. All opinions are my own.
#
#    followers_count  friends_count  statuses_count            join_time
# 0               67            109            2377  2016-09-23 22:19:13
# 1              293            891           25719  2011-09-18 11:23:00
# 2              323            305           13886  2017-12-01 12:45:15
# 3                0             24               2  2017-06-17 12:29:26
# 4               61            205            2335  2018-04-16 20:31:58

# %% [markdown]
# Or tabulate the number of times each `screen_name` tweeted, putting the most frequent tweeters at the top.

# %%
tweets['screen_name'].value_counts()
# Out:
# ham_gretsky        236
# Ashot_             205
# _30days30sites     159
# SherlockRobo       159
# AaronCuddeback     128
# wbmobile            96
# TheKratomCure       92
# jmdawson95          76
# KoightVampff        75
# craigbob99          69
# NoSQLDigest         63
# TheLinuxBot         63
# cassidyphoenyx      61
# _reactdev           57
# Bintata5            55
# LanaBintadiaz       52
# tempmedia1          52
# unpropaganda        52
# BeastOfWood         52
# vburrows1           52
# 100xcode            49
# DANEgerus           48
# jsmith6919          48
# nomuru2d            48
# PorteRougeTea       47
# javascriptd         47
# Belle_Vivant        46
# chompskymutt        43
# NonContactHogg      42
# tuns1999            40
#                   ...
# VickersGeronimo      1
# NHJeffersonian       1
# DisturbedSilenc      1
# kelownascott         1
# JustinBinoBrand      1
# DETECTIVE4LIFE       1
# MarkFiq_             1
# mich_country         1
# aschenbichl          1
# tksjewelry           1
# glenn_bilyeu         1
# BryceFlynn           1
# brimshae             1
# LightComingIn        1
# goonie_gangsta       1
# txcbth               1
# JonoHimself          1
# caloboldo01          1
# Deplorable4Trum      1
# mzeshanfaheem        1
# LizaVespi            1
# marykawirah          1
# blakemankansas       1
# carrotplush          1
# dexxxbers17          1
# JournoCheck          1
# Shmoe45              1
# rarara_chem          1
# ThsWiT               1
# CarrieSweet2017      1
# Name: screen_name, Length: 53128, dtype: int64

# %% [markdown]
# Using the simple subsetting we learned, we can now pull out all the tweets from `@cassidyphoenyx`.

# %%
tweets[tweets["screen_name"]=="cassidyphoenyx"]
# Out:
#                 tweet_time     screen_name  \
# 261    2019-01-30 06:56:43  cassidyphoenyx
# 1932   2019-01-30 01:36:45  cassidyphoenyx
# 2236   2019-01-30 01:02:00  cassidyphoenyx
# 2246   2019-01-30 01:00:46  cassidyphoenyx
# 2564   2019-01-30 00:24:36  cassidyphoenyx
# 10151  2019-01-29 13:54:34  cassidyphoenyx
# 20740  2019-01-29 02:43:41  cassidyphoenyx
# 20770  2019-01-29 02:40:29  cassidyphoenyx
# 20771  2019-01-29 02:40:17  cassidyphoenyx
# 21074  2019-01-29 02:11:02  cassidyphoenyx
# 21492  2019-01-29 01:38:50  cassidyphoenyx
# 21936  2019-01-29 01:05:42  cassidyphoenyx
# 22300  2019-01-29 00:41:10  cassidyphoenyx
# 22791  2019-01-29 00:12:07  cassidyphoenyx
# 27981  2019-01-28 20:41:33  cassidyphoenyx
# 28005  2019-01-28 20:40:36  cassidyphoenyx
# 29275  2019-01-28 19:53:22  cassidyphoenyx
# 29352  2019-01-28 19:50:51  cassidyphoenyx
# 29517  2019-01-28 19:44:45  cassidyphoenyx
# 29654  2019-01-28 19:40:19  cassidyphoenyx
# 30752  2019-01-28 19:05:47  cassidyphoenyx
# 35778  2019-01-28 16:38:47  cassidyphoenyx
# 63858  2019-01-27 16:36:55  cassidyphoenyx
# 65712  2019-01-27 14:02:20  cassidyphoenyx
# 65713  2019-01-27 14:02:13  cassidyphoenyx
# 69377  2019-01-27 01:18:32  cassidyphoenyx
# 69417  2019-01-27 01:11:08  cassidyphoenyx
# 69459  2019-01-27 01:03:06  cassidyphoenyx
# 69865  2019-01-26 23:53:11  cassidyphoenyx
# 69951  2019-01-26 23:33:03  cassidyphoenyx
# ...                    ...             ...
# 70291  2019-01-26 22:34:11  cassidyphoenyx
# 70295  2019-01-26 22:33:16  cassidyphoenyx
# 70297  2019-01-26 22:32:57  cassidyphoenyx
# 70308  2019-01-26 22:30:58  cassidyphoenyx
# 70358  2019-01-26 22:24:24  cassidyphoenyx
# 70378  2019-01-26 22:22:29  cassidyphoenyx
# 70470  2019-01-26 22:08:08  cassidyphoenyx
# 71583  2019-01-26 19:47:36  cassidyphoenyx
# 71795  2019-01-26 19:27:39  cassidyphoenyx
# 72908  2019-01-26 17:43:25  cassidyphoenyx
# 74214  2019-01-26 14:16:27  cassidyphoenyx
# 75238  2019-01-26 11:32:24  cassidyphoenyx
# 75304  2019-01-26 11:23:51  cassidyphoenyx
# 79926  2019-01-25 14:52:30  cassidyphoenyx
# 83017  2019-01-25 08:28:40  cassidyphoenyx
# 84207  2019-01-25 05:15:51  cassidyphoenyx
# 84212  2019-01-25 05:14:33  cassidyphoenyx
# 84222  2019-01-25 05:09:00  cassidyphoenyx
# 84229  2019-01-25 05:07:26  cassidyphoenyx
# 84310  2019-01-25 04:45:31  cassidyphoenyx
# 84316  2019-01-25 04:43:49  cassidyphoenyx
# 84434  2019-01-25 04:18:26  cassidyphoenyx
# 87758  2019-01-24 21:08:21  cassidyphoenyx
# 88000  2019-01-24 20:49:38  cassidyphoenyx
# 88115  2019-01-24 20:40:44  cassidyphoenyx
# 90589  2019-01-24 16:03:41  cassidyphoenyx
# 90631  2019-01-24 15:55:27  cassidyphoenyx
# 90695  2019-01-24 15:40:54  cassidyphoenyx
# 92167  2019-01-23 21:21:23  cassidyphoenyx
# 94571  2019-01-20 10:12:28  cassidyphoenyx
#
#                                                                                                                                                                                                                                                                                      full_text  \
# 261                                                                                                                                               RT @infolibnews: Tucker Carlson on Tuesday night covered the story of right-wing Twitter telling laid-off journalists to "learn to code" an…
# 1932                                                                                                                                           RT @USALoyalty1776: If Americans dont take notice of @jack’s BLATANT free speech violations &amp; bias to protect abusive “journalists” we are…
# 2236                                                                                                                                              RT @SelimSeesYou: Even in this, so many lies: the NPC meme did catch on. So much so twitter started having to ban it for hitting a little t…
# 2246                                                                                                                                                                           RT @awooooowa: If journalists don't like being told to learn to code,  they should just make their own twitter.
# 2564                                                                                                                                                                      RT @ColumbiaBugle: ROFL!!!!\n\nTucker Carlson on the “Learn to Code” Controversy on Twitter  https://t.co/L9NxNCJnvv
# 10151                                                                                                                                             RT @RubinReport: So Twitter is banning people who tweet #LearnToCode at journalists. I just reported a tweet which has information about wh…
# 20740                                                                                                                                                            RT @TweetBrettMac: Twitter vowing to go after people that tell laid off journalists to learn to code? https://t.co/3cB1LVI5aZ
# 20770                                                                                                                                              RT @The_War_Economy: I'm sure "journalists" successfully convincing Twitter to ban anybody that suggests to them that they should learn to…
# 20771                                                                                                                                             RT @Youth4_America: @PolitiBunny Journalist - there’s a war on the first amendment from the Trump admin       Same Journalist- Hi twitter c…
# 21074                                                                                                                                             RT @jeffgiesea: Here's how media has covered laid-off coal miners. This is why the #LearnToCode meme stings, as trolls taunt laid-off journ…
# 21492                                                                                                                                                                                                                                    RT @JoshLeCash: LEARN TO CODE https://t.co/FfqEDwcjzw
# 21936                                                                                                                                           RT @Timcast: Twitter user Paul Mackenzie, @paul94mck, appears to have tweeted #Learntocode 3 times and "learn to code" once.\n\nOne tweet was…
# 22300                                                                                                                                                                                    RT @TweetBrettMac: Someone was allegedly suspended for saying "Learn To Code" https://t.co/mV0pOjZqQe
# 22791                                                                                                                                             RT @BarrettWilson6: Journalist from @TorontoStar has perfectly reasonable reaction to my article about why regular people may feel resentme…
# 27981                                                                                                                                           RT @Timcast: He didnt even cover what "learn to code" was about or what was going on.\n\nJust took one activist, Talia Lavin, who posted some…
# 28005                                                                                                                                           RT @Timcast: In other words, nothing has changed they just explained why they are sanctioning people.\n\nOk so if you tweet "learn to code" a…
# 29275                                                                                                                                              RT @borzoombers: I just got to the part in Ship of Fools where Tucker talks about elites telling auto workers in Michigan to learn to code…
# 29352                                                                                                                                             RT @AUChizad: @GayPatriot Twitter banned the NPC meme because it was effective satire of the left. Now they're banning "learn to code" beca…
# 29517                                                                                                                                             RT @AnnCoulter: Wow -- "learn to code" is exactly what Sen. Marco Rubio told MILLIONS of Americans who lost their jobs due to mass immigrat…
# 29654                                                                                                                                              RT @LevineJonathan: I am told by a person in the know that tweeting "learn to code" at any recently laid off journalist will be treated as…
# 30752                                                                                                                                           RT @DonaldJTrumpJr: Is this real or trolling that no one caught? \n\nIf real, I wonder why no one cared when many of those same journalists t…
# 35778                                                                                                                                             RT @DonaldJTrumpJr: Could someone explain to me why if I tell my kids to “learn to code” it’s likely sound parenting, but if I told a journ…
# 63858                                                                @Timcast I didn't see any death threats,just "learn to code"messages which the media said were from 4chan but it isn't from 4chan.People on the right have been saying that for years when "journalists" lose their jobs.
# 65712                                                                                                                                         RT @prestonjbyrne: *Coal industry dies*\nJournalists: "Learn to code, miners."\n\n*Overfunded tech company dies*\nJournalists: "LOL Theranos 2.…
# 65713                                                                                                                                          RT @prestonjbyrne: "Learn to code."\nJournalists: "We'd be better coders than you would be journalists if you had to switch."\n\n"All I said w…
# 69377                                                                                                                                                                                    There's no magic wand,those jobs aren't coming back,they should learn to code https://t.co/JICCXDP0Bf
# 69417                                                                                                                                                                    RT @CarpeDonktum: Fired Journalists are Triggered by #LearnToCode, because THEY ARE THE CODE. https://t.co/lZnLjhTxRf
# 69459                                                                                                                                             RT @notwokieleaks: If you can’t see that “Learn to code” is mocking what the left says to displaced middle-America then you have no busines…
# 69865                                                                                                                                                                                                                                               @realDonaldTrump They should learn to code
# 69951                                                                                                                                                                                                            @sapna A good start,gotta work on those numbers,and they should learn to code
# ...                                                                                                                                                                                                                                                                                        ...
# 70291                                                                                                                                                                   RT @Annrhefn: They're really getting triggered by the #LearnToCode meme. 😂\n\nLearn. To. Code. https://t.co/TnyjyHWnXt
# 70295                                                                                                                                                                                                        RT @yourmomwarnedyu: @LaurenWeberHP @HuffPost Have you thought about #LearnToCode
# 70297                                                                                                                                             RT @Interchopper: #learntocode is hilarious because just last year #journalists were hitting unemployed coal miners with the same energy, a…
# 70308                                                                                                                                                                                                                    RT @CassandraRules: They should learn to code https://t.co/rr98VXeqJf
# 70358                                                                                                                                             RT @SaysSimonson: It’s weird seeing journalists try to craft some narrative that there’s a crisis around a bunch of randos telling people w…
# 70378                                                                                                                                                                                       RT @redsteeze: Telling someone “learn to code” is not targeted harassment. https://t.co/fUE86FRRM6
# 70470                                                                                                                                             RT @davereaboi: Dozens of journalists who think they’re authorities on the US political scene have never heard “learn to code” before today…
# 71583                                                                                                                                           RT @Cernovich: 👇🏻Journalists claiming “Learn to code” is a 4chan meme are lying.\n\n“Learn to code” was a “Let them eat cake” theme shared wi…
# 71795                                                                                                                                             RT @ramzpaul: We may lose articles like this due to the recent media layoffs. Hope you “learn to code” trolls are happy. https://t.co/w62S5…
# 72908                                                                                                                                                                                                                                                    Learn to code https://t.co/Zjh8FErRrK
# 74214                                                                                                                                             RT @jeffgiesea: Here's how media has covered laid-off coal miners. This is why the #LearnToCode meme stings, as trolls taunt laid-off journ…
# 75238                                                                                                                                                                                                       RT @Communism_Kills: Tacos are appropriate. Learn to code. https://t.co/jSOMqi3nNh
# 75304                                                                                                                                                                                                                                     RT @ramzpaul: Learn To Code. https://t.co/SRd1diW5Bn
# 79926                                                                                                                                                                                                                                                               @oliverdarcy Learn to code
# 83017                                                                                                                                                                    Journos Meltdown After Being Told 'Learn To Code' In Wake Of Mass Layoffs At HuffPo, Buzzfeed https://t.co/cYTHOSoBjs
# 84207                                                                                                                                             RT @casuist: @JuliaTheWriter Mocks the working classes for the de-industrialization of the U.S. hinterlands because globalization; wants co…
# 84212                                                                                                                                              RT @lateforapex: @bypatrickgeorge The "LEARN TO CODE" reply is effectively what coal miners, steel workers, auto workers and others in the…
# 84222                                                                                                                                              RT @distractseasily: @skeptical7th @chick_in_kiev No, it's because smug journos told blue collar workers to "just learn to code lol" after…
# 84229                                                                                                                                                                          RT @eric_ras: @bypatrickgeorge The jobs aren’t coming back. There’s not a magic wand. You should learn to code.
# 84310                                                                                                                                             RT @KatieS_1: Be a coal miner. Globalism railroads your livelihood, your town falls to ruin. Some kid in Manhattan takes time out from writ…
# 84316                                                                                                                                             RT @KatieS_1: “Learn to code” was the advice journalists offered in op-ed after op-ed to blue collar workers in the heartland as their indu…
# 84434                                                                                                                                                                                                                         @maxjrosenthal @jasoncherkis @LEBassett @nickpwing learn to code
# 87758  But that's what you say to factory workers,steel mill workers,coal miners,ranchers,farmers,truck drivers etc. that have been laid https://t.co/jBdQ6tJZkM don't GAF about everyday AMERICANS even when they have families to provide for so why should we GAF about you?Learn to cod...
# 88000  I'm not on 4chan We say learn to code because that's what you say to coal miners,factory workers,ranchers,truck drivers,steel mill workers and farmers when they get laid https://t.co/jBdQ6tJZkM DGAF about everyday AMERICANS why should we GAF about you?Learn to code https://t....
# 88115                                                                                                                                                                                                                                                    Learn to code https://t.co/Hb0T0z3w6o
# 90589                                                                                                                                           RT @ScottMGreer: Left-wing journos want all of their enemies destitute and their families ruined. \n\nBeing magnanimous, we just want journos…
# 90631                                                                                                                                                                                                                                                    Learn to code https://t.co/QvF6Ev4V84
# 90695                                                                                                                                                                                                                                 @oliverdarcy learn to code,those jobs aren't coming back
# 92167                                                                                                                                                                                                                                                              @ClaraJeffery Learn to code
# 94571                                                                                                                                                                                                                                                                       @AFP Learn to code
#
#                     id_str  \
# 261    1090579557189644292
# 1932   1090499034618519552
# 2236   1090490293303033856
# 2246   1090489980483293184
# 2564   1090480877522612226
# 10151  1090322326346969089
# 20740  1090153492919005189
# 20770  1090152685993644032
# 20771  1090152636291211264
# 21074  1090145276248117248
# 21492  1090137172613705728
# 21936  1090128833624313858
# 22300  1090122660749676545
# 22791  1090115349612249088
# 27981  1090062359350165505
# 28005  1090062119612092416
# 29275  1090050231532732416
# 29352  1090049598981320705
# 29517  1090048065828999168
# 29654  1090046951431815173
# 30752  1090038260867452928
# 35778  1090001266267381766
# 63858  1089638408325079040
# 65712  1089599505048190978
# 65713  1089599473888698369
# 69377  1089407287867908096
# 69417  1089405426955968512
# 69459  1089403406236688385
# 69865  1089385810519117824
# 69951  1089380743107825664
# ...                    ...
# 70291  1089365930076000256
# 70295  1089365697787060225
# 70297  1089365620414656512
# 70308  1089365121040859136
# 70358  1089363467348385792
# 70378  1089362984273616896
# 70470  1089359373284061184
# 71583  1089324005243400194
# 71795  1089318987605991424
# 72908  1089292752901324801
# 74214  1089240670370492417
# 75238  1089199386754727936
# 75304  1089197235823349765
# 79926  1088887354998300683
# 83017  1088790760835686402
# 84207  1088742235015966721
# 84212  1088741910615937025
# 84222  1088740511786172416
# 84229  1088740117592846336
# 84310  1088734603823726592
# 84316  1088734174398345217
# 84434  1088727784942374913
# 87758  1088619553737900032
# 88000  1088614843010240512
# 88115  1088612604011036674
# 90589  1088542879646138368
# 90631  1088540809924931586
# 90695  1088537147802558470
# 92167  1088260444920401920
# 94571  1087004944442540032
#
#                                                                    source  \
# 261    <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 1932   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2236   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2246   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 2564   <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 10151  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 20740  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 20770  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 20771  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 21074  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 21492  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 21936  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 22300  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 22791  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 27981  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 28005  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 29275  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 29352  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 29517  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 29654  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 30752  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 35778  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 63858  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 65712  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 65713  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 69377  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 69417  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 69459  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 69865  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 69951  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# ...                                                                   ...
# 70291  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70295  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70297  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70308  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70358  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70378  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 70470  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 71583  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 71795  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 72908  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 74214  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 75238  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 75304  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 79926  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 83017  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84207  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84212  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84222  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84229  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84310  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84316  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 84434  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 87758  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 88000  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 88115  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 90589  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 90631  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 90695  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 92167  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 94571  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#
#        retweet  retweet_count  favorite_count  \
# 261       True              4               0
# 1932      True            195               0
# 2236      True              3               0
# 2246      True             32               0
# 2564      True            397               0
# 10151     True           2532               0
# 20740     True              2               0
# 20770     True             22               0
# 20771     True              4               0
# 21074     True            517               0
# 21492     True            103               0
# 21936     True            247               0
# 22300     True             42               0
# 22791     True            158               0
# 27981     True             32               0
# 28005     True            100               0
# 29275     True            112               0
# 29352     True            165               0
# 29517     True            702               0
# 29654     True           2562               0
# 30752     True           5168               0
# 35778     True           7565               0
# 63858    False              0               1
# 65712     True           5312               0
# 65713     True            158               0
# 69377    False              1               1
# 69417     True             90               0
# 69459     True            290               0
# 69865    False              0               0
# 69951    False              0               0
# ...        ...            ...             ...
# 70291     True            117               0
# 70295     True              4               0
# 70297     True            322               0
# 70308     True             83               0
# 70358     True             15               0
# 70378     True            184               0
# 70470     True            254               0
# 71583     True            266               0
# 71795     True            391               0
# 72908    False              0               1
# 74214     True            517               0
# 75238     True             12               0
# 75304     True             20               0
# 79926    False              0               0
# 83017    False              0               0
# 84207     True             20               0
# 84212     True             54               0
# 84222     True             37               0
# 84229     True             45               0
# 84310     True            108               0
# 84316     True            164               0
# 84434    False              0               0
# 87758    False              1               1
# 88000    False              3               5
# 88115    False              0               0
# 90589     True            126               0
# 90631    False              0               0
# 90695    False              0               0
# 92167    False              0               0
# 94571    False              0               1
#
#                              description  followers_count  friends_count  \
# 261    Author for Black Widow Publishing             2724           2342
# 1932   Author for Black Widow Publishing             2724           2342
# 2236   Author for Black Widow Publishing             2724           2342
# 2246   Author for Black Widow Publishing             2724           2342
# 2564   Author for Black Widow Publishing             2724           2342
# 10151  Author for Black Widow Publishing             2724           2342
# 20740  Author for Black Widow Publishing             2724           2342
# 20770  Author for Black Widow Publishing             2724           2342
# 20771  Author for Black Widow Publishing             2724           2342
# 21074  Author for Black Widow Publishing             2724           2342
# 21492  Author for Black Widow Publishing             2724           2342
# 21936  Author for Black Widow Publishing             2724           2342
# 22300  Author for Black Widow Publishing             2724           2342
# 22791  Author for Black Widow Publishing             2724           2342
# 27981  Author for Black Widow Publishing             2724           2342
# 28005  Author for Black Widow Publishing             2724           2342
# 29275  Author for Black Widow Publishing             2724           2342
# 29352  Author for Black Widow Publishing             2724           2342
# 29517  Author for Black Widow Publishing             2724           2342
# 29654  Author for Black Widow Publishing             2724           2342
# 30752  Author for Black Widow Publishing             2724           2342
# 35778  Author for Black Widow Publishing             2724           2342
# 63858  Author for Black Widow Publishing             2725           2342
# 65712  Author for Black Widow Publishing             2725           2342
# 65713  Author for Black Widow Publishing             2725           2342
# 69377  Author for Black Widow Publishing             2725           2342
# 69417  Author for Black Widow Publishing             2725           2342
# 69459  Author for Black Widow Publishing             2725           2342
# 69865  Author for Black Widow Publishing             2725           2342
# 69951  Author for Black Widow Publishing             2725           2342
# ...                                  ...              ...            ...
# 70291  Author for Black Widow Publishing             2725           2342
# 70295  Author for Black Widow Publishing             2725           2342
# 70297  Author for Black Widow Publishing             2725           2342
# 70308  Author for Black Widow Publishing             2725           2342
# 70358  Author for Black Widow Publishing             2725           2342
# 70378  Author for Black Widow Publishing             2725           2342
# 70470  Author for Black Widow Publishing             2725           2342
# 71583  Author for Black Widow Publishing             2725           2342
# 71795  Author for Black Widow Publishing             2725           2342
# 72908  Author for Black Widow Publishing             2725           2342
# 74214  Author for Black Widow Publishing             2725           2342
# 75238  Author for Black Widow Publishing             2725           2342
# 75304  Author for Black Widow Publishing             2725           2342
# 79926  Author for Black Widow Publishing             2725           2342
# 83017  Author for Black Widow Publishing             2725           2342
# 84207  Author for Black Widow Publishing             2725           2342
# 84212  Author for Black Widow Publishing             2725           2342
# 84222  Author for Black Widow Publishing             2725           2342
# 84229  Author for Black Widow Publishing             2725           2342
# 84310  Author for Black Widow Publishing             2725           2342
# 84316  Author for Black Widow Publishing             2725           2342
# 84434  Author for Black Widow Publishing             2725           2342
# 87758  Author for Black Widow Publishing             2725           2342
# 88000  Author for Black Widow Publishing             2725           2342
# 88115  Author for Black Widow Publishing             2725           2342
# 90589  Author for Black Widow Publishing             2725           2342
# 90631  Author for Black Widow Publishing             2725           2342
# 90695  Author for Black Widow Publishing             2725           2342
# 92167  Author for Black Widow Publishing             2725           2342
# 94571  Author for Black Widow Publishing             2725           2342
#
#        statuses_count            join_time
# 261            401658  2015-03-05 22:58:51
# 1932           401658  2015-03-05 22:58:51
# 2236           401658  2015-03-05 22:58:51
# 2246           401658  2015-03-05 22:58:51
# 2564           401658  2015-03-05 22:58:51
# 10151          401658  2015-03-05 22:58:51
# 20740          401659  2015-03-05 22:58:51
# 20770          401659  2015-03-05 22:58:51
# 20771          401659  2015-03-05 22:58:51
# 21074          401659  2015-03-05 22:58:51
# 21492          401659  2015-03-05 22:58:51
# 21936          401659  2015-03-05 22:58:51
# 22300          401659  2015-03-05 22:58:51
# 22791          401659  2015-03-05 22:58:51
# 27981          401659  2015-03-05 22:58:51
# 28005          401659  2015-03-05 22:58:51
# 29275          401659  2015-03-05 22:58:51
# 29352          401659  2015-03-05 22:58:51
# 29517          401659  2015-03-05 22:58:51
# 29654          401659  2015-03-05 22:58:51
# 30752          401659  2015-03-05 22:58:51
# 35778          401659  2015-03-05 22:58:51
# 63858          401659  2015-03-05 22:58:51
# 65712          401659  2015-03-05 22:58:51
# 65713          401659  2015-03-05 22:58:51
# 69377          401659  2015-03-05 22:58:51
# 69417          401659  2015-03-05 22:58:51
# 69459          401659  2015-03-05 22:58:51
# 69865          401659  2015-03-05 22:58:51
# 69951          401659  2015-03-05 22:58:51
# ...               ...                  ...
# 70291          401659  2015-03-05 22:58:51
# 70295          401659  2015-03-05 22:58:51
# 70297          401659  2015-03-05 22:58:51
# 70308          401659  2015-03-05 22:58:51
# 70358          401659  2015-03-05 22:58:51
# 70378          401659  2015-03-05 22:58:51
# 70470          401659  2015-03-05 22:58:51
# 71583          401659  2015-03-05 22:58:51
# 71795          401659  2015-03-05 22:58:51
# 72908          401659  2015-03-05 22:58:51
# 74214          401659  2015-03-05 22:58:51
# 75238          401659  2015-03-05 22:58:51
# 75304          401659  2015-03-05 22:58:51
# 79926          401659  2015-03-05 22:58:51
# 83017          401659  2015-03-05 22:58:51
# 84207          401659  2015-03-05 22:58:51
# 84212          401659  2015-03-05 22:58:51
# 84222          401659  2015-03-05 22:58:51
# 84229          401659  2015-03-05 22:58:51
# 84310          401659  2015-03-05 22:58:51
# 84316          401659  2015-03-05 22:58:51
# 84434          401659  2015-03-05 22:58:51
# 87758          401664  2015-03-05 22:58:51
# 88000          401664  2015-03-05 22:58:51
# 88115          401664  2015-03-05 22:58:51
# 90589          401664  2015-03-05 22:58:51
# 90631          401664  2015-03-05 22:58:51
# 90695          401664  2015-03-05 22:58:51
# 92167          401664  2015-03-05 22:58:51
# 94571          401664  2015-03-05 22:58:51
#
# [61 rows x 13 columns]
