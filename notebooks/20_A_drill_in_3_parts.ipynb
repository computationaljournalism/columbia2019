# %% [markdown]
# #### The Mueller Report: A Drill in Three parts
#
# <img src=https://media.necn.com/images/652*367/trump-back-of-the-head.jpg width=500>
#
# Today we are going to refresh our skills a little and learn something new. You are going to be divided into four newsrooms. Over the course of the next two meetings, you will cover a piece of "breaking data," in this case the Mueller Report.
#
# **Part 1. Picture perfect**
#
# First, the report itself. Let's download the copy that was made available on April 18. Copies are floating all over the web but we'll stick to [the one hosted at Scribd](https://www.scribd.com/document/406726026/Mueller-report). It is the original and we are playing out this drill as if it was April 18. So, download the file and you have five minutes to tell me something about its contents. How is the argument structured? Who are the main characters? The significant places and times? **You can only work with this file.**
#
# Go!

# %%
# A baby timer

from time import sleep

for i in range(1,301):
    
    sleep(1)
    
    if i % 60:
        print(i, end=" ")
    else:
        print("\nminutes left:", 5-i/60)

# %% [markdown]
# What is the issue with the file? It is a PDF but *that* kind of PDF. Groups noticed immediately that the PDF was based on a scan, [prompting speculation about how it was produced.](https://www.theverge.com/2019/4/19/18508148/pdf-association-mueller-report-scanning-redaction-sad-formatting) There is another [retelling of the story in Quartz.](https://qz.com/1601873/the-pdf-of-the-mueller-report-has-been-updated-to-be-more-accessible/) While this version might be hopeless for text, what *is* it good for? Here's a hint.
# <br><br>
# <img src="https://i0.wp.com/flowingdata.com/wp-content/uploads/2019/04/all_pages-cropped.png?w=2427&ssl=1" width=500>
# <br><br>
#
# What other things can you do with the images? [Axios took a middle-of-the-road approach](https://www.axios.com/explore-a-detailed-version-of-the-mueller-report-5f7cab5b-9c53-46bc-abaa-bd6b7b3e6d66.html) and colored things according to people and places.
# <br><br>
# <img src="https://i1.wp.com/flowingdata.com/wp-content/uploads/2019/04/Tagged-Mueller-Report.png?w=1822&ssl=1" width=600>
# <br><br>
# Let's see what we can do here. We are going to use a newish package for working with PDF files. It's called `PyMuPdf` although the library name you load to use it is `fitz`. (There's some not particularly funny reason for this that for once I won't recount.)
#
# Let's install the package and fire it up!

# %%
# %%sh
# pip install PyMuPdf

# %% [markdown]
# We can use this package to now open the file we downloaded. Again, make sure the PDF is in the same folder as this notebook. We are going to use the function `open()` in the `fitz` library.  There is a simple tutorial [here](https://pymupdf.readthedocs.io/en/latest/tutorial/).

# %%
import fitz
doc = fitz.open("406726026-Mueller-report.pdf")
type(doc)

# %% [markdown]
# So we have a PDF document. Remember software objects have data and functions. In this case the `Document` object contains information like the number of pages...

# %%
doc.pageCount

# %% [markdown]
# ... and metadata about its creation.

# %%
doc.metadata

# %% [markdown]
# As we saw in the Quartz article, there is a table of contents that suggests a division of labor for redacting the document. Here's that division.

# %%
doc.getToC()

# %% [markdown]
# All of this is fine, but what we really want is the contents. Now, we have verified that this is a PDF made up of images. We can verify that and work with the data. So, let's start by loading a page. Here we use the method `.loadPage()` to grab one, say the 100th...

# %%
page = doc.loadPage(100)
type(page)

# %%
page

# %% [markdown]
# To grab the image, we can use a method called `.getPixmap()` that pulls the pixels. It will tell us how big the image is...

# %%
pix = page.getPixmap()
pix

# %% [markdown]
# ... and as we have done before, we can use a Jupyter tool to display it. We use the method `.getImageData()` from our pixelmap to return an image we can show.

# %%
from IPython.display import Image
Image(pix.getImageData(),width=300)

# %% [markdown]
# This is officially getting in the weeds, but we can pull the commands into one place and have a look by changing the index. We could, if we wantd to, scroll through the pages this way. Thankfully we have PDF previewers that make that a lot easier.
#
# Here we use a simpler command attached to the document and not the page, saving us a line of code.

# %%
pix = doc.getPagePixmap(200)
Image(pix.getImageData(),width=300)

# %% [markdown]
# Before we leave this, let's look at how we might make a grid in Jupyter. (There are so many ways to do this, it's crazy, but here's an easy one now that we're here.) What we'll do is export the image to file -- a `.png`. This is how we write one...

# %%
pix.writePNG("0.png")

# %% [markdown]
# ... and this is how we write 25 of them. You can use any offset you like so that you don't have to take the first 25. But anyway, print them out and then just use the `%%HTML` cell magic to display them in a table. Voila!

# %%
for i in range(25):
    pix = doc.getPagePixmap(i)
    pix.writePNG(str(i)+".png")

# %%
# %%HTML
# <table>
# <tr><td><img src=0.png width=100></td><td><img src=1.png width=100></td><td><img src=2.png width=100></td><td><img src=3.png width=100></td><td><img src=4.png width=100></td></tr>
# <tr><td><img src=5.png width=100></td><td><img src=6.png width=100></td><td><img src=7.png width=100></td><td><img src=8.png width=100></td><td><img src=9.png width=100></td></tr>
# <tr><td><img src=10.png width=100></td><td><img src=11.png width=100></td><td><img src=12.png width=100></td><td><img src=13.png width=100></td><td><img src=14.png width=100></td></tr>
# <tr><td><img src=15.png width=100></td><td><img src=16.png width=100></td><td><img src=17.png width=100></td><td><img src=18.png width=100></td><td><img src=19.png width=100></td></tr>
# <tr><td><img src=20.png width=100></td><td><img src=21.png width=100></td><td><img src=22.png width=100></td><td><img src=23.png width=100></td><td><img src=24.png width=100></td></tr>
# </table>

# %% [markdown]
# Now, PDF's have images and text. Just like we had a `.getPixmap()`, we also have `.getText()`.  In this case, we don't expect very much.

# %%
page = doc.loadPage(100)
page.getText("text")

# %% [markdown]
# Now, as we saw, the Mueller Report was quickly re-released using OCR to pull text from the scanned images. We'll again download from Scribd. Download [this version of the report now](https://www.scribd.com/document/406728825/Mueller-Report-searchable) and put it in the same folder as this notebook.
#
# Let's load it up and pull the text...

# %%
doc = fitz.open("406728825-Mueller-Report-searchable.pdf")

# %% [markdown]
# Now, we can `.load()` the page and use a method `.getText()` on the `page` object, or we can just `.getPageText()` directly from the `Document` object, saving us a little typing.

# %%
text = doc.getPageText(100)
text

# %% [markdown]
# What we get is a string. It's messy. We should try to find a cleaner version of the PDF that doesn't have so much stuff attached to it. Still, it will give us a taste of what we can do. We are going to start to use the text as data to help us understand what is being talked about.
#
# Now, without anything fancy, what can we do with each page of text? Give yourself 15 minutes on the clock above and try something out.

# %%
# your code here

# %% [markdown]
# Now we are going to add some formalism. We have already seen one platform for so-called naturla language processing, `TextBlob.` Today we are going to use `spacy` instead. [A complete guide](https://spacy.io/usage/spacy-101) will give you all you need to be fully dangerous.
#
# First, let's install the package...

# %%
# %%sh
# pip install spacy

# %% [markdown]
# ... and then install a language model. You will see from the documentation that there are a variety of languages available. We will stick with english.

# %%
# %%sh
# python -m spacy download en_core_web_sm

# %% [markdown]
# Now, let's start! We can create an object called `nlp` that will do the language processing for us. Here we take one sentence from page 81 and print the so-called named entities. You can see the kinds of things they recognize from [a spacy list.](https://spacy.io/api/annotation#named-entities)

# %%
print(doc.getPageText(81))

# %%
import spacy

# load spacy with a language model
nlp = spacy.load("en_core_web_sm")

# now perform a simple nlp computation on one of the sentences from page 81
parsed = nlp("Over the past few months, I have been working with a company based in Russia regarding the development of a Trump Tower-Moscow project in Moscow City.")

for ent in parsed.ents:
    print(ent.text.strip(), ent.label_)

# %% [markdown]
# We can also extract the so-called noun chunks (a noun plus words describing the noun).

# %%
for nc in parsed.noun_chunks:
    print(nc.text.strip())

# %% [markdown]
# And as with TextBlob we can pull sentences...

# %%
parsed = nlp(doc.getPageText(81))

for sent in parsed.sents:
    print(sent)
    print("--"*20)

# %% [markdown]
# Take another 10 minutes on the clock and do something with this new skill. What can you learn about the report?

# %%
# your code here

# %% [markdown]
# There is a lot more structure we can infer using spacy. Let's take the same sentence and consider the parts of speech it contains and the [dependency](https://spacy.io/api/annotation#dependency-parsing) between the words. It's probably a lot to get into the finer points of NLP today, but there are things we can do with just a little knowledge. The good thing is that most of what we need is [viewable graphically.](https://nlp.stanford.edu/software/dependencies_manual.pdf)

# %%
import spacy

# load spacy with a language model
nlp = spacy.load("en_core_web_sm")

# now perform a simple nlp computation on one of the sentences from page 100
parsed = nlp("Over the past few months, I have been working with a company based in Russia regarding the development of a Trump Tower-Moscow project in Moscow City.")

for token in parsed:
    print(token.text, token.dep_, token.head, token.head.pos_)

# %%
from spacy.symbols import nsubj, VERB

parsed = nlp(doc.getPageText(81))

verbs = []

for token in parsed:
    if token.dep == nsubj and token.text == "Cohen" and token.head.pos == VERB:
        verbs.append(token.head)

print(verbs)

# %% [markdown]
# And now what can you do?

# %%
# Your code here

# %% [markdown]
# **Part 2. The madding crowd**
#
# Now, let's have a look at Twitter and how this document spread across the network. We collected tweets from just before 11am to just around 11:20am. The total volume counts [is located here](https://github.com/computationaljournalism/columbia2019/raw/master/data/mueller_counts.json). Download the file and put it in the same folder as this notebook. Let's read it in and see what kind of thing we have. We are going to use `loads()` because we know it's a json object.

# %%
from json import loads
recs = loads(open("mueller_counts.json").read())
recs
# Out:
# ResourceWarning: unclosed file <_io.TextIOWrapper name='mueller_counts.json' mode='r' encoding='UTF-8'> [ipykernel_launcher.py:2]
# {'results': [{'timePeriod': '201904180000', 'count': 1284},
#   {'timePeriod': '201904180001', 'count': 1224},
#   {'timePeriod': '201904180002', 'count': 1272},
#   {'timePeriod': '201904180003', 'count': 1262},
#   {'timePeriod': '201904180004', 'count': 1295},
#   {'timePeriod': '201904180005', 'count': 1310},
#   {'timePeriod': '201904180006', 'count': 1189},
#   {'timePeriod': '201904180007', 'count': 1268},
#   {'timePeriod': '201904180008', 'count': 1258},
#   {'timePeriod': '201904180009', 'count': 1256},
#   {'timePeriod': '201904180010', 'count': 1255},
#   {'timePeriod': '201904180011', 'count': 1215},
#   {'timePeriod': '201904180012', 'count': 1282},
#   {'timePeriod': '201904180013', 'count': 1300},
#   {'timePeriod': '201904180014', 'count': 1312},
#   {'timePeriod': '201904180015', 'count': 1279},
#   {'timePeriod': '201904180016', 'count': 1313},
#   {'timePeriod': '201904180017', 'count': 1325},
#   {'timePeriod': '201904180018', 'count': 1313},
#   {'timePeriod': '201904180019', 'count': 1264},
#   {'timePeriod': '201904180020', 'count': 1279},
#   {'timePeriod': '201904180021', 'count': 1288},
#   {'timePeriod': '201904180022', 'count': 1208},
#   {'timePeriod': '201904180023', 'count': 1226},
#   {'timePeriod': '201904180024', 'count': 1282},
#   {'timePeriod': '201904180025', 'count': 1258},
#   {'timePeriod': '201904180026', 'count': 1384},
#   {'timePeriod': '201904180027', 'count': 1382},
#   {'timePeriod': '201904180028', 'count': 1409},
#   {'timePeriod': '201904180029', 'count': 1396},
#   {'timePeriod': '201904180030', 'count': 1473},
#   {'timePeriod': '201904180031', 'count': 1415},
#   {'timePeriod': '201904180032', 'count': 1461},
#   {'timePeriod': '201904180033', 'count': 1454},
#   {'timePeriod': '201904180034', 'count': 1383},
#   {'timePeriod': '201904180035', 'count': 1413},
#   {'timePeriod': '201904180036', 'count': 1495},
#   {'timePeriod': '201904180037', 'count': 1418},
#   {'timePeriod': '201904180038', 'count': 1398},
#   {'timePeriod': '201904180039', 'count': 1373},
#   {'timePeriod': '201904180040', 'count': 1477},
#   {'timePeriod': '201904180041', 'count': 1436},
#   {'timePeriod': '201904180042', 'count': 1363},
#   {'timePeriod': '201904180043', 'count': 1351},
#   {'timePeriod': '201904180044', 'count': 1434},
#   {'timePeriod': '201904180045', 'count': 1366},
#   {'timePeriod': '201904180046', 'count': 1417},
#   {'timePeriod': '201904180047', 'count': 1370},
#   {'timePeriod': '201904180048', 'count': 1298},
#   {'timePeriod': '201904180049', 'count': 1408},
#   {'timePeriod': '201904180050', 'count': 1457},
#   {'timePeriod': '201904180051', 'count': 1334},
#   {'timePeriod': '201904180052', 'count': 1377},
#   {'timePeriod': '201904180053', 'count': 1307},
#   {'timePeriod': '201904180054', 'count': 1366},
#   {'timePeriod': '201904180055', 'count': 1361},
#   {'timePeriod': '201904180056', 'count': 1321},
#   {'timePeriod': '201904180057', 'count': 1330},
#   {'timePeriod': '201904180058', 'count': 1353},
#   {'timePeriod': '201904180059', 'count': 1414},
#   {'timePeriod': '201904180100', 'count': 1388},
#   {'timePeriod': '201904180101', 'count': 1324},
#   {'timePeriod': '201904180102', 'count': 1301},
#   {'timePeriod': '201904180103', 'count': 1322},
#   {'timePeriod': '201904180104', 'count': 1305},
#   {'timePeriod': '201904180105', 'count': 1387},
#   {'timePeriod': '201904180106', 'count': 1378},
#   {'timePeriod': '201904180107', 'count': 1434},
#   {'timePeriod': '201904180108', 'count': 1383},
#   {'timePeriod': '201904180109', 'count': 1350},
#   {'timePeriod': '201904180110', 'count': 1410},
#   {'timePeriod': '201904180111', 'count': 1386},
#   {'timePeriod': '201904180112', 'count': 1392},
#   {'timePeriod': '201904180113', 'count': 1369},
#   {'timePeriod': '201904180114', 'count': 1370},
#   {'timePeriod': '201904180115', 'count': 1302},
#   {'timePeriod': '201904180116', 'count': 1301},
#   {'timePeriod': '201904180117', 'count': 1356},
#   {'timePeriod': '201904180118', 'count': 1323},
#   {'timePeriod': '201904180119', 'count': 1323},
#   {'timePeriod': '201904180120', 'count': 1322},
#   {'timePeriod': '201904180121', 'count': 1287},
#   {'timePeriod': '201904180122', 'count': 1387},
#   {'timePeriod': '201904180123', 'count': 1374},
#   {'timePeriod': '201904180124', 'count': 1469},
#   {'timePeriod': '201904180125', 'count': 1495},
#   {'timePeriod': '201904180126', 'count': 1537},
#   {'timePeriod': '201904180127', 'count': 1514},
#   {'timePeriod': '201904180128', 'count': 1456},
#   {'timePeriod': '201904180129', 'count': 1325},
#   {'timePeriod': '201904180130', 'count': 1325},
#   {'timePeriod': '201904180131', 'count': 1508},
#   {'timePeriod': '201904180132', 'count': 1413},
#   {'timePeriod': '201904180133', 'count': 1391},
#   {'timePeriod': '201904180134', 'count': 1452},
#   {'timePeriod': '201904180135', 'count': 1389},
#   {'timePeriod': '201904180136', 'count': 1442},
#   {'timePeriod': '201904180137', 'count': 1360},
#   {'timePeriod': '201904180138', 'count': 1358},
#   {'timePeriod': '201904180139', 'count': 1408},
#   {'timePeriod': '201904180140', 'count': 1353},
#   {'timePeriod': '201904180141', 'count': 1376},
#   {'timePeriod': '201904180142', 'count': 1354},
#   {'timePeriod': '201904180143', 'count': 1405},
#   {'timePeriod': '201904180144', 'count': 1387},
#   {'timePeriod': '201904180145', 'count': 1354},
#   {'timePeriod': '201904180146', 'count': 1445},
#   {'timePeriod': '201904180147', 'count': 1421},
#   {'timePeriod': '201904180148', 'count': 1409},
#   {'timePeriod': '201904180149', 'count': 1440},
#   {'timePeriod': '201904180150', 'count': 1462},
#   {'timePeriod': '201904180151', 'count': 1440},
#   {'timePeriod': '201904180152', 'count': 1398},
#   {'timePeriod': '201904180153', 'count': 1373},
#   {'timePeriod': '201904180154', 'count': 1370},
#   {'timePeriod': '201904180155', 'count': 1375},
#   {'timePeriod': '201904180156', 'count': 1406},
#   {'timePeriod': '201904180157', 'count': 1366},
#   {'timePeriod': '201904180158', 'count': 1416},
#   {'timePeriod': '201904180159', 'count': 1362},
#   {'timePeriod': '201904180200', 'count': 1385},
#   {'timePeriod': '201904180201', 'count': 1297},
#   {'timePeriod': '201904180202', 'count': 1259},
#   {'timePeriod': '201904180203', 'count': 1217},
#   {'timePeriod': '201904180204', 'count': 1305},
#   {'timePeriod': '201904180205', 'count': 1326},
#   {'timePeriod': '201904180206', 'count': 1249},
#   {'timePeriod': '201904180207', 'count': 1244},
#   {'timePeriod': '201904180208', 'count': 1225},
#   {'timePeriod': '201904180209', 'count': 1243},
#   {'timePeriod': '201904180210', 'count': 1284},
#   {'timePeriod': '201904180211', 'count': 1237},
#   {'timePeriod': '201904180212', 'count': 1274},
#   {'timePeriod': '201904180213', 'count': 1288},
#   {'timePeriod': '201904180214', 'count': 1313},
#   {'timePeriod': '201904180215', 'count': 1261},
#   {'timePeriod': '201904180216', 'count': 1299},
#   {'timePeriod': '201904180217', 'count': 1294},
#   {'timePeriod': '201904180218', 'count': 1285},
#   {'timePeriod': '201904180219', 'count': 1224},
#   {'timePeriod': '201904180220', 'count': 1353},
#   {'timePeriod': '201904180221', 'count': 1285},
#   {'timePeriod': '201904180222', 'count': 1267},
#   {'timePeriod': '201904180223', 'count': 1204},
#   {'timePeriod': '201904180224', 'count': 1237},
#   {'timePeriod': '201904180225', 'count': 1232},
#   {'timePeriod': '201904180226', 'count': 1295},
#   {'timePeriod': '201904180227', 'count': 1215},
#   {'timePeriod': '201904180228', 'count': 1199},
#   {'timePeriod': '201904180229', 'count': 1273},
#   {'timePeriod': '201904180230', 'count': 1297},
#   {'timePeriod': '201904180231', 'count': 1210},
#   {'timePeriod': '201904180232', 'count': 1234},
#   {'timePeriod': '201904180233', 'count': 1272},
#   {'timePeriod': '201904180234', 'count': 1291},
#   {'timePeriod': '201904180235', 'count': 1278},
#   {'timePeriod': '201904180236', 'count': 1241},
#   {'timePeriod': '201904180237', 'count': 1158},
#   {'timePeriod': '201904180238', 'count': 1159},
#   {'timePeriod': '201904180239', 'count': 1145},
#   {'timePeriod': '201904180240', 'count': 1222},
#   {'timePeriod': '201904180241', 'count': 1157},
#   {'timePeriod': '201904180242', 'count': 1222},
#   {'timePeriod': '201904180243', 'count': 1204},
#   {'timePeriod': '201904180244', 'count': 1171},
#   {'timePeriod': '201904180245', 'count': 1167},
#   {'timePeriod': '201904180246', 'count': 1252},
#   {'timePeriod': '201904180247', 'count': 1165},
#   {'timePeriod': '201904180248', 'count': 1147},
#   {'timePeriod': '201904180249', 'count': 1136},
#   {'timePeriod': '201904180250', 'count': 1145},
#   {'timePeriod': '201904180251', 'count': 1094},
#   {'timePeriod': '201904180252', 'count': 1124},
#   {'timePeriod': '201904180253', 'count': 1111},
#   {'timePeriod': '201904180254', 'count': 1160},
#   {'timePeriod': '201904180255', 'count': 1045},
#   {'timePeriod': '201904180256', 'count': 1021},
#   {'timePeriod': '201904180257', 'count': 1102},
#   {'timePeriod': '201904180258', 'count': 1028},
#   {'timePeriod': '201904180259', 'count': 1059},
#   {'timePeriod': '201904180300', 'count': 1109},
#   {'timePeriod': '201904180301', 'count': 1040},
#   {'timePeriod': '201904180302', 'count': 956},
#   {'timePeriod': '201904180303', 'count': 981},
#   {'timePeriod': '201904180304', 'count': 1020},
#   {'timePeriod': '201904180305', 'count': 971},
#   {'timePeriod': '201904180306', 'count': 1002},
#   {'timePeriod': '201904180307', 'count': 980},
#   {'timePeriod': '201904180308', 'count': 993},
#   {'timePeriod': '201904180309', 'count': 1003},
#   {'timePeriod': '201904180310', 'count': 952},
#   {'timePeriod': '201904180311', 'count': 995},
#   {'timePeriod': '201904180312', 'count': 981},
#   {'timePeriod': '201904180313', 'count': 930},
#   {'timePeriod': '201904180314', 'count': 1068},
#   {'timePeriod': '201904180315', 'count': 1017},
#   {'timePeriod': '201904180316', 'count': 980},
#   {'timePeriod': '201904180317', 'count': 1013},
#   {'timePeriod': '201904180318', 'count': 1018},
#   {'timePeriod': '201904180319', 'count': 937},
#   {'timePeriod': '201904180320', 'count': 1065},
#   {'timePeriod': '201904180321', 'count': 986},
#   {'timePeriod': '201904180322', 'count': 1021},
#   {'timePeriod': '201904180323', 'count': 990},
#   {'timePeriod': '201904180324', 'count': 1004},
#   {'timePeriod': '201904180325', 'count': 974},
#   {'timePeriod': '201904180326', 'count': 1007},
#   {'timePeriod': '201904180327', 'count': 1008},
#   {'timePeriod': '201904180328', 'count': 928},
#   {'timePeriod': '201904180329', 'count': 996},
#   {'timePeriod': '201904180330', 'count': 1007},
#   {'timePeriod': '201904180331', 'count': 954},
#   {'timePeriod': '201904180332', 'count': 867},
#   {'timePeriod': '201904180333', 'count': 867},
#   {'timePeriod': '201904180334', 'count': 873},
#   {'timePeriod': '201904180335', 'count': 827},
#   {'timePeriod': '201904180336', 'count': 826},
#   {'timePeriod': '201904180337', 'count': 858},
#   {'timePeriod': '201904180338', 'count': 861},
#   {'timePeriod': '201904180339', 'count': 832},
#   {'timePeriod': '201904180340', 'count': 865},
#   {'timePeriod': '201904180341', 'count': 907},
#   {'timePeriod': '201904180342', 'count': 903},
#   {'timePeriod': '201904180343', 'count': 829},
#   {'timePeriod': '201904180344', 'count': 851},
#   {'timePeriod': '201904180345', 'count': 809},
#   {'timePeriod': '201904180346', 'count': 806},
#   {'timePeriod': '201904180347', 'count': 800},
#   {'timePeriod': '201904180348', 'count': 829},
#   {'timePeriod': '201904180349', 'count': 859},
#   {'timePeriod': '201904180350', 'count': 759},
#   {'timePeriod': '201904180351', 'count': 787},
#   {'timePeriod': '201904180352', 'count': 796},
#   {'timePeriod': '201904180353', 'count': 793},
#   {'timePeriod': '201904180354', 'count': 717},
#   {'timePeriod': '201904180355', 'count': 741},
#   {'timePeriod': '201904180356', 'count': 755},
#   {'timePeriod': '201904180357', 'count': 815},
#   {'timePeriod': '201904180358', 'count': 768},
#   {'timePeriod': '201904180359', 'count': 743},
#   {'timePeriod': '201904180400', 'count': 776},
#   {'timePeriod': '201904180401', 'count': 723},
#   {'timePeriod': '201904180402', 'count': 770},
#   {'timePeriod': '201904180403', 'count': 749},
#   {'timePeriod': '201904180404', 'count': 690},
#   {'timePeriod': '201904180405', 'count': 739},
#   {'timePeriod': '201904180406', 'count': 767},
#   {'timePeriod': '201904180407', 'count': 707},
#   {'timePeriod': '201904180408', 'count': 775},
#   {'timePeriod': '201904180409', 'count': 700},
#   {'timePeriod': '201904180410', 'count': 725},
#   {'timePeriod': '201904180411', 'count': 737},
#   {'timePeriod': '201904180412', 'count': 719},
#   {'timePeriod': '201904180413', 'count': 688},
#   {'timePeriod': '201904180414', 'count': 673},
#   {'timePeriod': '201904180415', 'count': 651},
#   {'timePeriod': '201904180416', 'count': 635},
#   {'timePeriod': '201904180417', 'count': 710},
#   {'timePeriod': '201904180418', 'count': 667},
#   {'timePeriod': '201904180419', 'count': 714},
#   {'timePeriod': '201904180420', 'count': 701},
#   {'timePeriod': '201904180421', 'count': 683},
#   {'timePeriod': '201904180422', 'count': 661},
#   {'timePeriod': '201904180423', 'count': 725},
#   {'timePeriod': '201904180424', 'count': 708},
#   {'timePeriod': '201904180425', 'count': 687},
#   {'timePeriod': '201904180426', 'count': 673},
#   {'timePeriod': '201904180427', 'count': 671},
#   {'timePeriod': '201904180428', 'count': 682},
#   {'timePeriod': '201904180429', 'count': 718},
#   {'timePeriod': '201904180430', 'count': 656},
#   {'timePeriod': '201904180431', 'count': 597},
#   {'timePeriod': '201904180432', 'count': 597},
#   {'timePeriod': '201904180433', 'count': 654},
#   {'timePeriod': '201904180434', 'count': 633},
#   {'timePeriod': '201904180435', 'count': 636},
#   {'timePeriod': '201904180436', 'count': 584},
#   {'timePeriod': '201904180437', 'count': 577},
#   {'timePeriod': '201904180438', 'count': 632},
#   {'timePeriod': '201904180439', 'count': 568},
#   {'timePeriod': '201904180440', 'count': 592},
#   {'timePeriod': '201904180441', 'count': 560},
#   {'timePeriod': '201904180442', 'count': 550},
#   {'timePeriod': '201904180443', 'count': 575},
#   {'timePeriod': '201904180444', 'count': 579},
#   {'timePeriod': '201904180445', 'count': 593},
#   {'timePeriod': '201904180446', 'count': 540},
#   {'timePeriod': '201904180447', 'count': 520},
#   {'timePeriod': '201904180448', 'count': 551},
#   {'timePeriod': '201904180449', 'count': 562},
#   {'timePeriod': '201904180450', 'count': 562},
#   {'timePeriod': '201904180451', 'count': 576},
#   {'timePeriod': '201904180452', 'count': 586},
#   {'timePeriod': '201904180453', 'count': 579},
#   {'timePeriod': '201904180454', 'count': 542},
#   {'timePeriod': '201904180455', 'count': 615},
#   {'timePeriod': '201904180456', 'count': 559},
#   {'timePeriod': '201904180457', 'count': 526},
#   {'timePeriod': '201904180458', 'count': 514},
#   {'timePeriod': '201904180459', 'count': 570},
#   {'timePeriod': '201904180500', 'count': 578},
#   {'timePeriod': '201904180501', 'count': 545},
#   {'timePeriod': '201904180502', 'count': 523},
#   {'timePeriod': '201904180503', 'count': 529},
#   {'timePeriod': '201904180504', 'count': 518},
#   {'timePeriod': '201904180505', 'count': 525},
#   {'timePeriod': '201904180506', 'count': 477},
#   {'timePeriod': '201904180507', 'count': 447},
#   {'timePeriod': '201904180508', 'count': 496},
#   {'timePeriod': '201904180509', 'count': 482},
#   {'timePeriod': '201904180510', 'count': 480},
#   {'timePeriod': '201904180511', 'count': 455},
#   {'timePeriod': '201904180512', 'count': 451},
#   {'timePeriod': '201904180513', 'count': 483},
#   {'timePeriod': '201904180514', 'count': 520},
#   {'timePeriod': '201904180515', 'count': 510},
#   {'timePeriod': '201904180516', 'count': 514},
#   {'timePeriod': '201904180517', 'count': 513},
#   {'timePeriod': '201904180518', 'count': 470},
#   {'timePeriod': '201904180519', 'count': 460},
#   {'timePeriod': '201904180520', 'count': 438},
#   {'timePeriod': '201904180521', 'count': 474},
#   {'timePeriod': '201904180522', 'count': 466},
#   {'timePeriod': '201904180523', 'count': 499},
#   {'timePeriod': '201904180524', 'count': 439},
#   {'timePeriod': '201904180525', 'count': 463},
#   {'timePeriod': '201904180526', 'count': 480},
#   {'timePeriod': '201904180527', 'count': 475},
#   {'timePeriod': '201904180528', 'count': 503},
#   {'timePeriod': '201904180529', 'count': 453},
#   {'timePeriod': '201904180530', 'count': 451},
#   {'timePeriod': '201904180531', 'count': 423},
#   {'timePeriod': '201904180532', 'count': 441},
#   {'timePeriod': '201904180533', 'count': 458},
#   {'timePeriod': '201904180534', 'count': 455},
#   {'timePeriod': '201904180535', 'count': 436},
#   {'timePeriod': '201904180536', 'count': 448},
#   {'timePeriod': '201904180537', 'count': 414},
#   {'timePeriod': '201904180538', 'count': 412},
#   {'timePeriod': '201904180539', 'count': 440},
#   {'timePeriod': '201904180540', 'count': 398},
#   {'timePeriod': '201904180541', 'count': 414},
#   {'timePeriod': '201904180542', 'count': 475},
#   {'timePeriod': '201904180543', 'count': 381},
#   {'timePeriod': '201904180544', 'count': 432},
#   {'timePeriod': '201904180545', 'count': 382},
#   {'timePeriod': '201904180546', 'count': 401},
#   {'timePeriod': '201904180547', 'count': 417},
#   {'timePeriod': '201904180548', 'count': 377},
#   {'timePeriod': '201904180549', 'count': 413},
#   {'timePeriod': '201904180550', 'count': 382},
#   {'timePeriod': '201904180551', 'count': 367},
#   {'timePeriod': '201904180552', 'count': 354},
#   {'timePeriod': '201904180553', 'count': 404},
#   {'timePeriod': '201904180554', 'count': 366},
#   {'timePeriod': '201904180555', 'count': 364},
#   {'timePeriod': '201904180556', 'count': 403},
#   {'timePeriod': '201904180557', 'count': 349},
#   {'timePeriod': '201904180558', 'count': 378},
#   {'timePeriod': '201904180559', 'count': 382},
#   {'timePeriod': '201904180600', 'count': 418},
#   {'timePeriod': '201904180601', 'count': 404},
#   {'timePeriod': '201904180602', 'count': 357},
#   {'timePeriod': '201904180603', 'count': 353},
#   {'timePeriod': '201904180604', 'count': 354},
#   {'timePeriod': '201904180605', 'count': 325},
#   {'timePeriod': '201904180606', 'count': 365},
#   {'timePeriod': '201904180607', 'count': 309},
#   {'timePeriod': '201904180608', 'count': 328},
#   {'timePeriod': '201904180609', 'count': 351},
#   {'timePeriod': '201904180610', 'count': 324},
#   {'timePeriod': '201904180611', 'count': 363},
#   {'timePeriod': '201904180612', 'count': 366},
#   {'timePeriod': '201904180613', 'count': 338},
#   {'timePeriod': '201904180614', 'count': 376},
#   {'timePeriod': '201904180615', 'count': 382},
#   {'timePeriod': '201904180616', 'count': 343},
#   {'timePeriod': '201904180617', 'count': 322},
#   {'timePeriod': '201904180618', 'count': 369},
#   {'timePeriod': '201904180619', 'count': 346},
#   {'timePeriod': '201904180620', 'count': 349},
#   {'timePeriod': '201904180621', 'count': 350},
#   {'timePeriod': '201904180622', 'count': 309},
#   {'timePeriod': '201904180623', 'count': 315},
#   {'timePeriod': '201904180624', 'count': 294},
#   {'timePeriod': '201904180625', 'count': 341},
#   {'timePeriod': '201904180626', 'count': 293},
#   {'timePeriod': '201904180627', 'count': 296},
#   {'timePeriod': '201904180628', 'count': 353},
#   {'timePeriod': '201904180629', 'count': 306},
#   {'timePeriod': '201904180630', 'count': 315},
#   {'timePeriod': '201904180631', 'count': 316},
#   {'timePeriod': '201904180632', 'count': 300},
#   {'timePeriod': '201904180633', 'count': 289},
#   {'timePeriod': '201904180634', 'count': 306},
#   {'timePeriod': '201904180635', 'count': 302},
#   {'timePeriod': '201904180636', 'count': 279},
#   {'timePeriod': '201904180637', 'count': 318},
#   {'timePeriod': '201904180638', 'count': 346},
#   {'timePeriod': '201904180639', 'count': 292},
#   {'timePeriod': '201904180640', 'count': 265},
#   {'timePeriod': '201904180641', 'count': 295},
#   {'timePeriod': '201904180642', 'count': 317},
#   {'timePeriod': '201904180643', 'count': 267},
#   {'timePeriod': '201904180644', 'count': 291},
#   {'timePeriod': '201904180645', 'count': 275},
#   {'timePeriod': '201904180646', 'count': 246},
#   {'timePeriod': '201904180647', 'count': 260},
#   {'timePeriod': '201904180648', 'count': 277},
#   {'timePeriod': '201904180649', 'count': 272},
#   {'timePeriod': '201904180650', 'count': 277},
#   {'timePeriod': '201904180651', 'count': 280},
#   {'timePeriod': '201904180652', 'count': 298},
#   {'timePeriod': '201904180653', 'count': 259},
#   {'timePeriod': '201904180654', 'count': 258},
#   {'timePeriod': '201904180655', 'count': 278},
#   {'timePeriod': '201904180656', 'count': 294},
#   {'timePeriod': '201904180657', 'count': 267},
#   {'timePeriod': '201904180658', 'count': 262},
#   {'timePeriod': '201904180659', 'count': 260},
#   {'timePeriod': '201904180700', 'count': 360},
#   {'timePeriod': '201904180701', 'count': 291},
#   {'timePeriod': '201904180702', 'count': 294},
#   {'timePeriod': '201904180703', 'count': 343},
#   {'timePeriod': '201904180704', 'count': 301},
#   {'timePeriod': '201904180705', 'count': 300},
#   {'timePeriod': '201904180706', 'count': 310},
#   {'timePeriod': '201904180707', 'count': 318},
#   {'timePeriod': '201904180708', 'count': 284},
#   {'timePeriod': '201904180709', 'count': 325},
#   {'timePeriod': '201904180710', 'count': 296},
#   {'timePeriod': '201904180711', 'count': 284},
#   {'timePeriod': '201904180712', 'count': 266},
#   {'timePeriod': '201904180713', 'count': 258},
#   {'timePeriod': '201904180714', 'count': 272},
#   {'timePeriod': '201904180715', 'count': 253},
#   {'timePeriod': '201904180716', 'count': 269},
#   {'timePeriod': '201904180717', 'count': 266},
#   {'timePeriod': '201904180718', 'count': 265},
#   {'timePeriod': '201904180719', 'count': 247},
#   {'timePeriod': '201904180720', 'count': 265},
#   {'timePeriod': '201904180721', 'count': 276},
#   {'timePeriod': '201904180722', 'count': 227},
#   {'timePeriod': '201904180723', 'count': 261},
#   {'timePeriod': '201904180724', 'count': 267},
#   {'timePeriod': '201904180725', 'count': 249},
#   {'timePeriod': '201904180726', 'count': 235},
#   {'timePeriod': '201904180727', 'count': 248},
#   {'timePeriod': '201904180728', 'count': 249},
#   {'timePeriod': '201904180729', 'count': 250},
#   {'timePeriod': '201904180730', 'count': 229},
#   {'timePeriod': '201904180731', 'count': 225},
#   {'timePeriod': '201904180732', 'count': 261},
#   {'timePeriod': '201904180733', 'count': 198},
#   {'timePeriod': '201904180734', 'count': 209},
#   {'timePeriod': '201904180735', 'count': 232},
#   {'timePeriod': '201904180736', 'count': 225},
#   {'timePeriod': '201904180737', 'count': 251},
#   {'timePeriod': '201904180738', 'count': 220},
#   {'timePeriod': '201904180739', 'count': 227},
#   {'timePeriod': '201904180740', 'count': 228},
#   {'timePeriod': '201904180741', 'count': 252},
#   {'timePeriod': '201904180742', 'count': 236},
#   {'timePeriod': '201904180743', 'count': 212},
#   {'timePeriod': '201904180744', 'count': 199},
#   {'timePeriod': '201904180745', 'count': 215},
#   {'timePeriod': '201904180746', 'count': 215},
#   {'timePeriod': '201904180747', 'count': 234},
#   {'timePeriod': '201904180748', 'count': 223},
#   {'timePeriod': '201904180749', 'count': 241},
#   {'timePeriod': '201904180750', 'count': 217},
#   {'timePeriod': '201904180751', 'count': 208},
#   {'timePeriod': '201904180752', 'count': 224},
#   {'timePeriod': '201904180753', 'count': 232},
#   {'timePeriod': '201904180754', 'count': 221},
#   {'timePeriod': '201904180755', 'count': 210},
#   {'timePeriod': '201904180756', 'count': 197},
#   {'timePeriod': '201904180757', 'count': 196},
#   {'timePeriod': '201904180758', 'count': 175},
#   {'timePeriod': '201904180759', 'count': 211},
#   {'timePeriod': '201904180800', 'count': 228},
#   {'timePeriod': '201904180801', 'count': 201},
#   {'timePeriod': '201904180802', 'count': 218},
#   {'timePeriod': '201904180803', 'count': 202},
#   {'timePeriod': '201904180804', 'count': 208},
#   {'timePeriod': '201904180805', 'count': 225},
#   {'timePeriod': '201904180806', 'count': 206},
#   {'timePeriod': '201904180807', 'count': 211},
#   {'timePeriod': '201904180808', 'count': 200},
#   {'timePeriod': '201904180809', 'count': 227},
#   {'timePeriod': '201904180810', 'count': 207},
#   {'timePeriod': '201904180811', 'count': 214},
#   {'timePeriod': '201904180812', 'count': 207},
#   {'timePeriod': '201904180813', 'count': 217},
#   {'timePeriod': '201904180814', 'count': 193},
#   {'timePeriod': '201904180815', 'count': 200},
#   {'timePeriod': '201904180816', 'count': 226},
#   {'timePeriod': '201904180817', 'count': 245},
#   {'timePeriod': '201904180818', 'count': 230},
#   {'timePeriod': '201904180819', 'count': 207},
#   {'timePeriod': '201904180820', 'count': 207},
#   {'timePeriod': '201904180821', 'count': 208},
#   {'timePeriod': '201904180822', 'count': 215},
#   {'timePeriod': '201904180823', 'count': 224},
#   {'timePeriod': '201904180824', 'count': 234},
#   {'timePeriod': '201904180825', 'count': 209},
#   {'timePeriod': '201904180826', 'count': 228},
#   {'timePeriod': '201904180827', 'count': 174},
#   {'timePeriod': '201904180828', 'count': 213},
#   {'timePeriod': '201904180829', 'count': 247},
#   {'timePeriod': '201904180830', 'count': 231},
#   {'timePeriod': '201904180831', 'count': 228},
#   {'timePeriod': '201904180832', 'count': 194},
#   {'timePeriod': '201904180833', 'count': 202},
#   {'timePeriod': '201904180834', 'count': 223},
#   {'timePeriod': '201904180835', 'count': 194},
#   {'timePeriod': '201904180836', 'count': 214},
#   {'timePeriod': '201904180837', 'count': 219},
#   {'timePeriod': '201904180838', 'count': 213},
#   {'timePeriod': '201904180839', 'count': 211},
#   {'timePeriod': '201904180840', 'count': 203},
#   {'timePeriod': '201904180841', 'count': 214},
#   {'timePeriod': '201904180842', 'count': 213},
#   {'timePeriod': '201904180843', 'count': 233},
#   {'timePeriod': '201904180844', 'count': 225},
#   {'timePeriod': '201904180845', 'count': 217},
#   {'timePeriod': '201904180846', 'count': 218},
#   {'timePeriod': '201904180847', 'count': 209},
#   {'timePeriod': '201904180848', 'count': 211},
#   {'timePeriod': '201904180849', 'count': 211},
#   {'timePeriod': '201904180850', 'count': 227},
#   {'timePeriod': '201904180851', 'count': 192},
#   {'timePeriod': '201904180852', 'count': 234},
#   {'timePeriod': '201904180853', 'count': 233},
#   {'timePeriod': '201904180854', 'count': 211},
#   {'timePeriod': '201904180855', 'count': 247},
#   {'timePeriod': '201904180856', 'count': 260},
#   {'timePeriod': '201904180857', 'count': 214},
#   {'timePeriod': '201904180858', 'count': 212},
#   {'timePeriod': '201904180859', 'count': 219},
#   {'timePeriod': '201904180900', 'count': 257},
#   {'timePeriod': '201904180901', 'count': 242},
#   {'timePeriod': '201904180902', 'count': 255},
#   {'timePeriod': '201904180903', 'count': 229},
#   {'timePeriod': '201904180904', 'count': 245},
#   {'timePeriod': '201904180905', 'count': 223},
#   {'timePeriod': '201904180906', 'count': 234},
#   {'timePeriod': '201904180907', 'count': 205},
#   {'timePeriod': '201904180908', 'count': 229},
#   {'timePeriod': '201904180909', 'count': 237},
#   {'timePeriod': '201904180910', 'count': 232},
#   {'timePeriod': '201904180911', 'count': 224},
#   {'timePeriod': '201904180912', 'count': 237},
#   {'timePeriod': '201904180913', 'count': 218},
#   {'timePeriod': '201904180914', 'count': 221},
#   {'timePeriod': '201904180915', 'count': 219},
#   {'timePeriod': '201904180916', 'count': 218},
#   {'timePeriod': '201904180917', 'count': 213},
#   {'timePeriod': '201904180918', 'count': 220},
#   {'timePeriod': '201904180919', 'count': 228},
#   {'timePeriod': '201904180920', 'count': 264},
#   {'timePeriod': '201904180921', 'count': 233},
#   {'timePeriod': '201904180922', 'count': 244},
#   {'timePeriod': '201904180923', 'count': 257},
#   {'timePeriod': '201904180924', 'count': 250},
#   {'timePeriod': '201904180925', 'count': 238},
#   {'timePeriod': '201904180926', 'count': 272},
#   {'timePeriod': '201904180927', 'count': 254},
#   {'timePeriod': '201904180928', 'count': 230},
#   {'timePeriod': '201904180929', 'count': 242},
#   {'timePeriod': '201904180930', 'count': 270},
#   {'timePeriod': '201904180931', 'count': 275},
#   {'timePeriod': '201904180932', 'count': 239},
#   {'timePeriod': '201904180933', 'count': 254},
#   {'timePeriod': '201904180934', 'count': 281},
#   {'timePeriod': '201904180935', 'count': 286},
#   {'timePeriod': '201904180936', 'count': 263},
#   {'timePeriod': '201904180937', 'count': 286},
#   {'timePeriod': '201904180938', 'count': 296},
#   {'timePeriod': '201904180939', 'count': 268},
#   {'timePeriod': '201904180940', 'count': 313},
#   {'timePeriod': '201904180941', 'count': 287},
#   {'timePeriod': '201904180942', 'count': 279},
#   {'timePeriod': '201904180943', 'count': 301},
#   {'timePeriod': '201904180944', 'count': 296},
#   {'timePeriod': '201904180945', 'count': 325},
#   {'timePeriod': '201904180946', 'count': 345},
#   {'timePeriod': '201904180947', 'count': 319},
#   {'timePeriod': '201904180948', 'count': 286},
#   {'timePeriod': '201904180949', 'count': 293},
#   {'timePeriod': '201904180950', 'count': 323},
#   {'timePeriod': '201904180951', 'count': 286},
#   {'timePeriod': '201904181612', 'count': 4447},
#   {'timePeriod': '201904181613', 'count': 4396},
#   {'timePeriod': '201904181614', 'count': 4459},
#   {'timePeriod': '201904181615', 'count': 4374},
#   {'timePeriod': '201904181616', 'count': 4391},
#   {'timePeriod': '201904181617', 'count': 4349},
#   {'timePeriod': '201904181618', 'count': 4363},
#   {'timePeriod': '201904181619', 'count': 4415},
#   {'timePeriod': '201904181620', 'count': 4308},
#   {'timePeriod': '201904181621', 'count': 4452},
#   {'timePeriod': '201904181622', 'count': 4410},
#   {'timePeriod': '201904181623', 'count': 4435},
#   {'timePeriod': '201904181624', 'count': 4572},
#   {'timePeriod': '201904181625', 'count': 4537},
#   {'timePeriod': '201904181626', 'count': 4362},
#   {'timePeriod': '201904181627', 'count': 4375},
#   {'timePeriod': '201904181628', 'count': 4499},
#   {'timePeriod': '201904181629', 'count': 4512},
#   {'timePeriod': '201904181630', 'count': 4548},
#   {'timePeriod': '201904181631', 'count': 4574},
#   {'timePeriod': '201904181632', 'count': 4437},
#   {'timePeriod': '201904181633', 'count': 4283},
#   {'timePeriod': '201904181634', 'count': 4306},
#   {'timePeriod': '201904181635', 'count': 4357},
#   {'timePeriod': '201904181636', 'count': 4219},
#   {'timePeriod': '201904181637', 'count': 4247},
#   {'timePeriod': '201904181638', 'count': 4212},
#   {'timePeriod': '201904181639', 'count': 4187},
#   ...],
#  'totalCount': 2762046,
#  'requestParameters': {'bucket': 'minute',
#   'fromDate': '201904180000',
#   'toDate': '201904190000'}}

# %% [markdown]
# Ha! A dictionary that contains a list of dictionaries. That list of dictionaries can be made into a data frame trivially with each list element being a row. Remember?

# %%
from pandas import DataFrame

counts = DataFrame.from_records(recs["results"])
counts.head()
# Out:
#    count    timePeriod
# 0   1284  201904180000
# 1   1224  201904180001
# 2   1272  201904180002
# 3   1262  201904180003
# 4   1295  201904180004

# %% [markdown]
# The time here is awful - to fix the string, we are going to use our datetime conversions. We need to specify the format of the string, meaning which numbers mean what. Clearly it's year-month-day-hour-minute. The format we need to decode this can be [found here](http://strftime.org/). We'll add a new column called `time` to represent a time object and not just a really big number.

# %%
from pandas import to_datetime
counts["time"] = to_datetime(counts["timePeriod"].astype(str),format="%Y%m%d%H%M")
counts.head()
# Out:
#    count    timePeriod                time
# 0   1284  201904180000 2019-04-18 00:00:00
# 1   1224  201904180001 2019-04-18 00:01:00
# 2   1272  201904180002 2019-04-18 00:02:00
# 3   1262  201904180003 2019-04-18 00:03:00
# 4   1295  201904180004 2019-04-18 00:04:00

# %% [markdown]
# What are we irresistably drawn to do?

# %%
from plotly.plotly import iplot, sign_in
from plotly.graph_objs import Scatter, Figure

# sign into the service (get your own credentials!)
sign_in("cocteautt","8YLww0QuMPVQ46meAMaq")

# create a plot of a single line tracking tweets over time
myplot_parts = [Scatter(x=counts["time"],y=counts["count"])]

# make a figure from this line plot...
myfigure = Figure(data=myplot_parts)

# ... and plot it (the filename is a convention plotly needs in case you want to use it later)
iplot(myfigure,filename="madding")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~cocteautt/4668.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Now, set another 15 minutes on the clock and let's see what we can do!

# %%
# your code here
